# %%
from __future__ import print_function
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from numpy import linalg as LA
import json
import math
# %matplotlib inline
import matplotlib.pyplot as plt
from json import dumps
import re
import string

# %%
with open('data/data.json') as json_file:  
    data = json.load(json_file)

# %%
print(data[0])
# Out:
# {'Market Category': 'Factory Tuner,Luxury,High-Performance', 'reviews': [{'Review_Title': 'Orange Bimmer', 'Review': " I have owned many different cars from nearly every major manufacturer and this car is, by far, the most fun to drive.It is almost as exciting to drive as the Gallardo I drove in Vegas, and this car I can actually own (and do).It is in it's break-in period, but it is still a blast to drive through back roads.Averaging about 20/21 mpg currently.", 'Review_Date': ' on 11/28/11 16:12 PM (PST)', 'Rating': 4.625, 'Author_Name': '330zhp ', 'Vehicle_Title': '2011 BMW 1 Series M Coupe 2dr Coupe (3.0L 6cyl Turbo 6M)'}, {'Review_Title': 'M-power and distinctiveness for cheap', 'Review': ' Picked up with Euro delivery in Munich, now back in states.Germans went nuts over this car (Valencia Orange probably helped!) and was great fun to drive on the Autobahn and at the Nurburgring.Traded in a 2009 M3 and I prefer this car despite the fact that Randy Pobst "hates it!"For people like me that have driven on the track with fast cars Porsch GT3 and the M3,eg) but are no way race drivers this car rocks.Looks have been criticized, but looks butch to me and the general public seems to agree.No auto means few posers and limited production means I have only seen one other on the street (in white).Only changes I would like:better plastics, more aggressive factory tune>', 'Review_Date': ' on 11/17/11 17:44 PM (PST)', 'Rating': 4.75, 'Author_Name': 'dhwhitney ', 'Vehicle_Title': '2011 BMW 1 Series M Coupe 2dr Coupe (3.0L 6cyl Turbo 6M)'}], 'Transmission Type': 'MANUAL', 'Year': 2011, 'Driven_Wheels': 'rear wheel drive', 'Year_Make_Model': '2011 BMW 1 Series M', 'city mpg': 19, 'Model': '1 Series M', 'Vehicle Size': 'Compact', 'Popularity': 3916, 'Vehicle Style': 'Coupe', 'MSRP': 46135, 'highway MPG': 26, 'Make': 'BMW'}

# %%
num_cars = len(data)

# %%
def tokenize(text):
    return re.findall(r'[a-z]+', text.lower())

# %%
for car in data:
    car['Appended Reviews'] = ""
    for review in car['reviews']:
        new_review = (re.sub('[0-9]+', '', review['Review'])).lower()
        car['Appended Reviews'] = car['Appended Reviews'] + new_review + ' '
    car['Tokenized Reviews'] = tokenize(car['Appended Reviews'])

# %%
print(data[0]['Appended Reviews'])
# Out:
#  i have owned many different cars from nearly every major manufacturer and this car is, by far, the most fun to drive.it is almost as exciting to drive as the gallardo i drove in vegas, and this car i can actually own (and do).it is in it's break-in period, but it is still a blast to drive through back roads.averaging about / mpg currently.  picked up with euro delivery in munich, now back in states.germans went nuts over this car (valencia orange probably helped!) and was great fun to drive on the autobahn and at the nurburgring.traded in a  m and i prefer this car despite the fact that randy pobst "hates it!"for people like me that have driven on the track with fast cars porsch gt and the m,eg) but are no way race drivers this car rocks.looks have been criticized, but looks butch to me and the general public seems to agree.no auto means few posers and limited production means i have only seen one other on the street (in white).only changes i would like:better plastics, more aggressive factory tune>

# %%
print(data[0]['Tokenized Reviews'])
# Out:
# ['i', 'have', 'owned', 'many', 'different', 'cars', 'from', 'nearly', 'every', 'major', 'manufacturer', 'and', 'this', 'car', 'is', 'by', 'far', 'the', 'most', 'fun', 'to', 'drive', 'it', 'is', 'almost', 'as', 'exciting', 'to', 'drive', 'as', 'the', 'gallardo', 'i', 'drove', 'in', 'vegas', 'and', 'this', 'car', 'i', 'can', 'actually', 'own', 'and', 'do', 'it', 'is', 'in', 'it', 's', 'break', 'in', 'period', 'but', 'it', 'is', 'still', 'a', 'blast', 'to', 'drive', 'through', 'back', 'roads', 'averaging', 'about', 'mpg', 'currently', 'picked', 'up', 'with', 'euro', 'delivery', 'in', 'munich', 'now', 'back', 'in', 'states', 'germans', 'went', 'nuts', 'over', 'this', 'car', 'valencia', 'orange', 'probably', 'helped', 'and', 'was', 'great', 'fun', 'to', 'drive', 'on', 'the', 'autobahn', 'and', 'at', 'the', 'nurburgring', 'traded', 'in', 'a', 'm', 'and', 'i', 'prefer', 'this', 'car', 'despite', 'the', 'fact', 'that', 'randy', 'pobst', 'hates', 'it', 'for', 'people', 'like', 'me', 'that', 'have', 'driven', 'on', 'the', 'track', 'with', 'fast', 'cars', 'porsch', 'gt', 'and', 'the', 'm', 'eg', 'but', 'are', 'no', 'way', 'race', 'drivers', 'this', 'car', 'rocks', 'looks', 'have', 'been', 'criticized', 'but', 'looks', 'butch', 'to', 'me', 'and', 'the', 'general', 'public', 'seems', 'to', 'agree', 'no', 'auto', 'means', 'few', 'posers', 'and', 'limited', 'production', 'means', 'i', 'have', 'only', 'seen', 'one', 'other', 'on', 'the', 'street', 'in', 'white', 'only', 'changes', 'i', 'would', 'like', 'better', 'plastics', 'more', 'aggressive', 'factory', 'tune']

# %%
n_feats = 5000
doc_by_vocab = np.empty([len(data), n_feats])

def build_vectorizer(max_features, stop_words, max_df=0.8, min_df=20, norm='l2'):
    """Returns a TfidfVectorizer object with the above preprocessing properties.
    
    Params: {max_features: Integer,
             max_df: Float,
             min_df: Float,
             norm: String,
             stop_words: String}
    Returns: TfidfVectorizer
    """
    return TfidfVectorizer(max_features=max_features, min_df=min_df, max_df=max_df, stop_words=stop_words, norm=norm)
    
tfidf_vec = build_vectorizer(n_feats, "english")
doc_by_vocab = tfidf_vec.fit_transform([d['Appended Reviews'] for d in data]).toarray()
index_to_vocab = {i:v for i, v in enumerate(tfidf_vec.get_feature_names())}
# Out:
# /Users/Stephanie/venv4300a5/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:1039: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
index_to_vocab
# Out:
# {0: 'aaa',
#  1: 'ability',
#  2: 'able',
#  3: 'abs',
#  4: 'absolute',
#  5: 'absolutely',
#  6: 'absolutly',
#  7: 'abuse',
#  8: 'ac',
#  9: 'acadia',
#  10: 'accelerate',
#  11: 'accelerated',
#  12: 'accelerates',
#  13: 'accelerating',
#  14: 'acceleration',
#  15: 'accelerator',
#  16: 'accent',
#  17: 'accents',
#  18: 'accept',
#  19: 'acceptable',
#  20: 'access',
#  21: 'accessible',
#  22: 'accessories',
#  23: 'accessory',
#  24: 'accident',
#  25: 'accidentally',
#  26: 'accidents',
#  27: 'accommodate',
#  28: 'accommodating',
#  29: 'accord',
#  30: 'according',
#  31: 'accords',
#  32: 'account',
#  33: 'accurate',
#  34: 'accustomed',
#  35: 'achieve',
#  36: 'achieved',
#  37: 'acknowledge',
#  38: 'act',
#  39: 'acting',
#  40: 'action',
#  41: 'activate',
#  42: 'activated',
#  43: 'activation',
#  44: 'active',
#  45: 'activities',
#  46: 'acts',
#  47: 'actual',
#  48: 'actually',
#  49: 'actuator',
#  50: 'acura',
#  51: 'acuras',
#  52: 'ad',
#  53: 'adapter',
#  54: 'adaptive',
#  55: 'add',
#  56: 'added',
#  57: 'adding',
#  58: 'addition',
#  59: 'additional',
#  60: 'additionally',
#  61: 'address',
#  62: 'addressed',
#  63: 'addresses',
#  64: 'adds',
#  65: 'adequate',
#  66: 'adequately',
#  67: 'adjust',
#  68: 'adjustable',
#  69: 'adjusted',
#  70: 'adjusting',
#  71: 'adjustment',
#  72: 'adjustments',
#  73: 'adjusts',
#  74: 'admit',
#  75: 'admitted',
#  76: 'admittedly',
#  77: 'adult',
#  78: 'adults',
#  79: 'advance',
#  80: 'advanced',
#  81: 'advantage',
#  82: 'advantages',
#  83: 'advertise',
#  84: 'advertised',
#  85: 'advertising',
#  86: 'advice',
#  87: 'advise',
#  88: 'advised',
#  89: 'advisor',
#  90: 'affect',
#  91: 'affected',
#  92: 'afford',
#  93: 'affordable',
#  94: 'afraid',
#  95: 'aftermarket',
#  96: 'afternoon',
#  97: 'age',
#  98: 'aged',
#  99: 'ages',
#  100: 'aggressive',
#  101: 'aggressively',
#  102: 'agile',
#  103: 'agility',
#  104: 'aging',
#  105: 'ago',
#  106: 'agree',
#  107: 'agreed',
#  108: 'ahead',
#  109: 'aid',
#  110: 'aids',
#  111: 'ain',
#  112: 'air',
#  113: 'airbag',
#  114: 'airbags',
#  115: 'airport',
#  116: 'al',
#  117: 'alarm',
#  118: 'alarms',
#  119: 'alaska',
#  120: 'albeit',
#  121: 'alert',
#  122: 'alerts',
#  123: 'aligned',
#  124: 'alignment',
#  125: 'alike',
#  126: 'alive',
#  127: 'allow',
#  128: 'allowed',
#  129: 'allowing',
#  130: 'allows',
#  131: 'alloy',
#  132: 'alloys',
#  133: 'alot',
#  134: 'alpine',
#  135: 'alright',
#  136: 'alternative',
#  137: 'alternatives',
#  138: 'alternator',
#  139: 'altima',
#  140: 'altitude',
#  141: 'altogether',
#  142: 'aluminum',
#  143: 'amazed',
#  144: 'amazing',
#  145: 'amazingly',
#  146: 'amazon',
#  147: 'ambient',
#  148: 'amenities',
#  149: 'america',
#  150: 'american',
#  151: 'americans',
#  152: 'amg',
#  153: 'amounts',
#  154: 'amp',
#  155: 'ample',
#  156: 'android',
#  157: 'angeles',
#  158: 'angle',
#  159: 'angled',
#  160: 'angles',
#  161: 'angry',
#  162: 'anniversary',
#  163: 'annoyance',
#  164: 'annoyances',
#  165: 'annoyed',
#  166: 'annoying',
#  167: 'annual',
#  168: 'answer',
#  169: 'answers',
#  170: 'antenna',
#  171: 'anti',
#  172: 'anticipated',
#  173: 'antifreeze',
#  174: 'anxiety',
#  175: 'anybody',
#  176: 'anymore',
#  177: 'anytime',
#  178: 'anyways',
#  179: 'apart',
#  180: 'app',
#  181: 'apparent',
#  182: 'apparently',
#  183: 'appeal',
#  184: 'appealing',
#  185: 'appear',
#  186: 'appearance',
#  187: 'appeared',
#  188: 'appears',
#  189: 'apple',
#  190: 'application',
#  191: 'applied',
#  192: 'apply',
#  193: 'appointed',
#  194: 'appointment',
#  195: 'appointments',
#  196: 'appreciate',
#  197: 'appreciated',
#  198: 'approach',
#  199: 'approaching',
#  200: 'appropriate',
#  201: 'approx',
#  202: 'approximately',
#  203: 'apps',
#  204: 'apr',
#  205: 'april',
#  206: 'area',
#  207: 'areas',
#  208: 'aren',
#  209: 'argue',
#  210: 'arizona',
#  211: 'arm',
#  212: 'armrest',
#  213: 'armrests',
#  214: 'arms',
#  215: 'arrive',
#  216: 'arrived',
#  217: 'arrow',
#  218: 'art',
#  219: 'asap',
#  220: 'ashamed',
#  221: 'asian',
#  222: 'aside',
#  223: 'ask',
#  224: 'asked',
#  225: 'asking',
#  226: 'asks',
#  227: 'aspect',
#  228: 'aspects',
#  229: 'asphalt',
#  230: 'aspirated',
#  231: 'ass',
#  232: 'assembled',
#  233: 'assembly',
#  234: 'assist',
#  235: 'assistance',
#  236: 'associated',
#  237: 'assume',
#  238: 'assumed',
#  239: 'assuming',
#  240: 'assurance',
#  241: 'assured',
#  242: 'atlanta',
#  243: 'ats',
#  244: 'attached',
#  245: 'attempt',
#  246: 'attempted',
#  247: 'attempting',
#  248: 'attempts',
#  249: 'attention',
#  250: 'attitude',
#  251: 'attract',
#  252: 'attracted',
#  253: 'attractive',
#  254: 'attributes',
#  255: 'auction',
#  256: 'audi',
#  257: 'audible',
#  258: 'audio',
#  259: 'audis',
#  260: 'aug',
#  261: 'august',
#  262: 'austin',
#  263: 'auto',
#  264: 'autobahn',
#  265: 'automatic',
#  266: 'automatically',
#  267: 'automobile',
#  268: 'automobiles',
#  269: 'automotive',
#  270: 'autonomous',
#  271: 'autos',
#  272: 'aux',
#  273: 'auxiliary',
#  274: 'avail',
#  275: 'availability',
#  276: 'available',
#  277: 'avalanche',
#  278: 'avalon',
#  279: 'ave',
#  280: 'avenue',
#  281: 'average',
#  282: 'averaged',
#  283: 'averages',
#  284: 'averaging',
#  285: 'avg',
#  286: 'avoid',
#  287: 'avoidance',
#  288: 'avoided',
#  289: 'aware',
#  290: 'away',
#  291: 'awd',
#  292: 'awesome',
#  293: 'awful',
#  294: 'awhile',
#  295: 'awkward',
#  296: 'awsome',
#  297: 'axle',
#  298: 'axles',
#  299: 'az',
#  300: 'baby',
#  301: 'backed',
#  302: 'background',
#  303: 'backing',
#  304: 'backs',
#  305: 'backseat',
#  306: 'backup',
#  307: 'backwards',
#  308: 'bad',
#  309: 'badge',
#  310: 'badly',
#  311: 'bag',
#  312: 'bags',
#  313: 'balance',
#  314: 'balanced',
#  315: 'ball',
#  316: 'band',
#  317: 'bang',
#  318: 'banger',
#  319: 'banging',
#  320: 'bank',
#  321: 'bar',
#  322: 'bare',
#  323: 'barely',
#  324: 'bargain',
#  325: 'bars',
#  326: 'base',
#  327: 'based',
#  328: 'basic',
#  329: 'basically',
#  330: 'basis',
#  331: 'bass',
#  332: 'bat',
#  333: 'batteries',
#  334: 'battery',
#  335: 'bay',
#  336: 'bbb',
#  337: 'bc',
#  338: 'beach',
#  339: 'beam',
#  340: 'beams',
#  341: 'bear',
#  342: 'bearing',
#  343: 'bearings',
#  344: 'beast',
#  345: 'beat',
#  346: 'beating',
#  347: 'beats',
#  348: 'beautiful',
#  349: 'beautifully',
#  350: 'beauty',
#  351: 'bed',
#  352: 'beep',
#  353: 'beeping',
#  354: 'beeps',
#  355: 'beetle',
#  356: 'began',
#  357: 'begin',
#  358: 'beginning',
#  359: 'begs',
#  360: 'behavior',
#  361: 'beige',
#  362: 'believe',
#  363: 'believed',
#  364: 'bell',
#  365: 'bells',
#  366: 'beloved',
#  367: 'belt',
#  368: 'belts',
#  369: 'bench',
#  370: 'bend',
#  371: 'benefit',
#  372: 'benefits',
#  373: 'bent',
#  374: 'bentley',
#  375: 'benz',
#  376: 'best',
#  377: 'bet',
#  378: 'better',
#  379: 'beware',
#  380: 'bias',
#  381: 'biased',
#  382: 'bicycle',
#  383: 'big',
#  384: 'bigger',
#  385: 'biggest',
#  386: 'bike',
#  387: 'bikes',
#  388: 'bills',
#  389: 'bimmer',
#  390: 'bin',
#  391: 'bird',
#  392: 'birds',
#  393: 'birthday',
#  394: 'bit',
#  395: 'bits',
#  396: 'black',
#  397: 'blades',
#  398: 'blah',
#  399: 'blame',
#  400: 'bland',
#  401: 'blank',
#  402: 'blast',
#  403: 'blazer',
#  404: 'blend',
#  405: 'blessing',
#  406: 'blew',
#  407: 'blind',
#  408: 'blindspot',
#  409: 'blinker',
#  410: 'blizzard',
#  411: 'block',
#  412: 'blocked',
#  413: 'blocking',
#  414: 'blocks',
#  415: 'blow',
#  416: 'blower',
#  417: 'blowing',
#  418: 'blown',
#  419: 'blows',
#  420: 'blue',
#  421: 'bluetooth',
#  422: 'bmw',
#  423: 'bmws',
#  424: 'board',
#  425: 'boards',
#  426: 'boat',
#  427: 'body',
#  428: 'bold',
#  429: 'bolsters',
#  430: 'bolt',
#  431: 'bolts',
#  432: 'bone',
#  433: 'boned',
#  434: 'bones',
#  435: 'bonneville',
#  436: 'bonus',
#  437: 'book',
#  438: 'books',
#  439: 'boost',
#  440: 'booster',
#  441: 'boot',
#  442: 'boots',
#  443: 'bored',
#  444: 'boring',
#  445: 'bose',
#  446: 'boss',
#  447: 'boston',
#  448: 'bother',
#  449: 'bothered',
#  450: 'bothers',
#  451: 'bottle',
#  452: 'bottoms',
#  453: 'bought',
#  454: 'bounce',
#  455: 'bouncy',
#  456: 'box',
#  457: 'boxer',
#  458: 'boxes',
#  459: 'boxster',
#  460: 'boxy',
#  461: 'boy',
#  462: 'boyfriend',
#  463: 'boys',
#  464: 'bracket',
#  465: 'brainer',
#  466: 'brake',
#  467: 'brakes',
#  468: 'braking',
#  469: 'brand',
#  470: 'brands',
#  471: 'break',
#  472: 'breakdown',
#  473: 'breaker',
#  474: 'breaking',
#  475: 'breaks',
#  476: 'breath',
#  477: 'breeze',
#  478: 'bridgestone',
#  479: 'brief',
#  480: 'bright',
#  481: 'brilliant',
#  482: 'bring',
#  483: 'bringing',
#  484: 'brings',
#  485: 'broke',
#  486: 'broken',
#  487: 'brother',
#  488: 'brought',
#  489: 'brown',
#  490: 'bs',
#  491: 'btw',
#  492: 'buck',
#  493: 'bucket',
#  494: 'buckle',
#  495: 'bucks',
#  496: 'budget',
#  497: 'bug',
#  498: 'buggy',
#  499: 'bugs',
#  500: 'buick',
#  501: 'buicks',
#  502: 'build',
#  503: 'building',
#  504: 'builds',
#  505: 'built',
#  506: 'bulb',
#  507: 'bulbs',
#  508: 'bulky',
#  509: 'bullet',
#  510: 'bulletin',
#  511: 'bulletproof',
#  512: 'bummer',
#  513: 'bump',
#  514: 'bumped',
#  515: 'bumper',
#  516: 'bumpers',
#  517: 'bumps',
#  518: 'bumpy',
#  519: 'bunch',
#  520: 'burn',
#  521: 'burned',
#  522: 'burning',
#  523: 'burns',
#  524: 'bus',
#  525: 'bushing',
#  526: 'bushings',
#  527: 'business',
#  528: 'busy',
#  529: 'butt',
#  530: 'butter',
#  531: 'button',
#  532: 'buttons',
#  533: 'buy',
#  534: 'buyback',
#  535: 'buyer',
#  536: 'buyers',
#  537: 'buying',
#  538: 'buys',
#  539: 'buzz',
#  540: 'buzzing',
#  541: 'bye',
#  542: 'ca',
#  543: 'cab',
#  544: 'cabin',
#  545: 'cable',
#  546: 'cables',
#  547: 'cabriolet',
#  548: 'caddy',
#  549: 'cadillac',
#  550: 'cadillacs',
#  551: 'cake',
#  552: 'cal',
#  553: 'calculated',
#  554: 'caliber',
#  555: 'california',
#  556: 'caliper',
#  557: 'calipers',
#  558: 'called',
#  559: 'calling',
#  560: 'calls',
#  561: 'cam',
#  562: 'camaro',
#  563: 'camaros',
#  564: 'came',
#  565: 'camera',
#  566: 'cameras',
#  567: 'camper',
#  568: 'camping',
#  569: 'camry',
#  570: 'camrys',
#  571: 'canada',
#  572: 'canadian',
#  573: 'cancel',
#  574: 'canyon',
#  575: 'cap',
#  576: 'capabilities',
#  577: 'capability',
#  578: 'capable',
#  579: 'capacity',
#  580: 'captain',
#  581: 'captains',
#  582: 'car',
#  583: 'caravan',
#  584: 'carbon',
#  585: 'card',
#  586: 'care',
#  587: 'cared',
#  588: 'careful',
#  589: 'carefully',
#  590: 'cares',
#  591: 'carfax',
#  592: 'cargo',
#  593: 'carlo',
#  594: 'carmax',
#  595: 'carolina',
#  596: 'carpet',
#  597: 'carplay',
#  598: 'carried',
#  599: 'carrier',
#  600: 'carries',
#  601: 'carry',
#  602: 'carrying',
#  603: 'cars',
#  604: 'cart',
#  605: 'case',
#  606: 'cases',
#  607: 'cash',
#  608: 'cassette',
#  609: 'cat',
#  610: 'catalytic',
#  611: 'catch',
#  612: 'catcher',
#  613: 'catches',
#  614: 'catching',
#  615: 'categories',
#  616: 'category',
#  617: 'caught',
#  618: 'cause',
#  619: 'caused',
#  620: 'causes',
#  621: 'causing',
#  622: 'caution',
#  623: 'cavalier',
#  624: 'cavernous',
#  625: 'cayenne',
#  626: 'cayman',
#  627: 'cc',
#  628: 'cd',
#  629: 'cds',
#  630: 'ceiling',
#  631: 'celica',
#  632: 'cell',
#  633: 'center',
#  634: 'central',
#  635: 'cents',
#  636: 'century',
#  637: 'certain',
#  638: 'certainly',
#  639: 'certified',
#  640: 'chain',
#  641: 'chair',
#  642: 'chairs',
#  643: 'challenge',
#  644: 'challenger',
#  645: 'challenging',
#  646: 'champ',
#  647: 'chance',
#  648: 'change',
#  649: 'changed',
#  650: 'changer',
#  651: 'changes',
#  652: 'changing',
#  653: 'channel',
#  654: 'channels',
#  655: 'character',
#  656: 'characteristic',
#  657: 'characteristics',
#  658: 'charge',
#  659: 'charged',
#  660: 'charger',
#  661: 'chargers',
#  662: 'charges',
#  663: 'charging',
#  664: 'charm',
#  665: 'chassis',
#  666: 'cheap',
#  667: 'cheaper',
#  668: 'cheapest',
#  669: 'cheaply',
#  670: 'check',
#  671: 'checked',
#  672: 'checking',
#  673: 'checks',
#  674: 'cherokee',
#  675: 'chev',
#  676: 'chevrolet',
#  677: 'chevy',
#  678: 'chevys',
#  679: 'chicago',
#  680: 'child',
#  681: 'children',
#  682: 'chip',
#  683: 'chipped',
#  684: 'chipping',
#  685: 'chips',
#  686: 'choice',
#  687: 'choices',
#  688: 'choose',
#  689: 'choosing',
#  690: 'choppy',
#  691: 'chore',
#  692: 'chose',
#  693: 'chosen',
#  694: 'christmas',
#  695: 'chrome',
#  696: 'chrysler',
#  697: 'circle',
#  698: 'circumstances',
#  699: 'city',
#  700: 'civic',
#  701: 'civics',
#  702: 'cl',
#  703: 'cla',
#  704: 'claim',
#  705: 'claimed',
#  706: 'claiming',
#  707: 'claims',
#  708: 'class',
#  709: 'classic',
#  710: 'classy',
#  711: 'clean',
#  712: 'cleaned',
#  713: 'cleaner',
#  714: 'cleaning',
#  715: 'clear',
#  716: 'clearance',
#  717: 'clearly',
#  718: 'click',
#  719: 'clicking',
#  720: 'clicks',
#  721: 'clients',
#  722: 'climate',
#  723: 'climb',
#  724: 'climbing',
#  725: 'clip',
#  726: 'clips',
#  727: 'clock',
#  728: 'close',
#  729: 'closed',
#  730: 'closely',
#  731: 'closer',
#  732: 'closest',
#  733: 'closing',
#  734: 'cloth',
#  735: 'clothes',
#  736: 'clothing',
#  737: 'cloud',
#  738: 'club',
#  739: 'clubs',
#  740: 'clue',
#  741: 'clumsy',
#  742: 'clunk',
#  743: 'clunking',
#  744: 'clunks',
#  745: 'clunky',
#  746: 'cluster',
#  747: 'clutch',
#  748: 'coast',
#  749: 'coasting',
#  750: 'coat',
#  751: 'cobalt',
#  752: 'cobra',
#  753: 'cockpit',
#  754: 'code',
#  755: 'codes',
#  756: 'coffee',
#  757: 'coil',
#  758: 'coils',
#  759: 'coin',
#  760: 'cold',
#  761: 'colder',
#  762: 'college',
#  763: 'collision',
#  764: 'color',
#  765: 'colorado',
#  766: 'colored',
#  767: 'colors',
#  768: 'column',
#  769: 'com',
#  770: 'combination',
#  771: 'combine',
#  772: 'combined',
#  773: 'combines',
#  774: 'combo',
#  775: 'come',
#  776: 'comes',
#  777: 'comfort',
#  778: 'comfortable',
#  779: 'comfortably',
#  780: 'comforts',
#  781: 'comfy',
#  782: 'coming',
#  783: 'command',
#  784: 'commands',
#  785: 'comment',
#  786: 'commented',
#  787: 'comments',
#  788: 'commercial',
#  789: 'common',
#  790: 'community',
#  791: 'commute',
#  792: 'commuter',
#  793: 'commutes',
#  794: 'commuting',
#  795: 'compact',
#  796: 'companies',
#  797: 'company',
#  798: 'comparable',
#  799: 'comparably',
#  800: 'compare',
#  801: 'compared',
#  802: 'compares',
#  803: 'comparing',
#  804: 'comparison',
#  805: 'compartment',
#  806: 'compartments',
#  807: 'compass',
#  808: 'compatible',
#  809: 'compensate',
#  810: 'compete',
#  811: 'competent',
#  812: 'competes',
#  813: 'competing',
#  814: 'competition',
#  815: 'competitive',
#  816: 'competitor',
#  817: 'competitors',
#  818: 'complain',
#  819: 'complained',
#  820: 'complaining',
#  821: 'complains',
#  822: 'complaint',
#  823: 'complaints',
#  824: 'complements',
#  825: 'complete',
#  826: 'completed',
#  827: 'completely',
#  828: 'complex',
#  829: 'compliant',
#  830: 'complicated',
#  831: 'compliment',
#  832: 'compliments',
#  833: 'component',
#  834: 'components',
#  835: 'composed',
#  836: 'compression',
#  837: 'compressor',
#  838: 'compromise',
#  839: 'compromised',
#  840: 'compromises',
#  841: 'computer',
#  842: 'concept',
#  843: 'concern',
#  844: 'concerned',
#  845: 'concerning',
#  846: 'concerns',
#  847: 'conclusion',
#  848: 'concrete',
#  849: 'condenser',
#  850: 'condition',
#  851: 'conditioner',
#  852: 'conditioning',
#  853: 'conditions',
#  854: 'confidence',
#  855: 'confident',
#  856: 'configuration',
#  857: 'confirm',
#  858: 'confirmed',
#  859: 'confortable',
#  860: 'confused',
#  861: 'confusing',
#  862: 'connect',
#  863: 'connected',
#  864: 'connecting',
#  865: 'connection',
#  866: 'connections',
#  867: 'connectivity',
#  868: 'connector',
#  869: 'connects',
#  870: 'cons',
#  871: 'conservative',
#  872: 'conservatively',
#  873: 'consider',
#  874: 'considerable',
#  875: 'considerably',
#  876: 'consideration',
#  877: 'considered',
#  878: 'considering',
#  879: 'consistent',
#  880: 'consistently',
#  881: 'console',
#  882: 'constant',
#  883: 'constantly',
#  884: 'construction',
#  885: 'consumer',
#  886: 'consumers',
#  887: 'consuming',
#  888: 'consumption',
#  889: 'contact',
#  890: 'contacted',
#  891: 'contacts',
#  892: 'content',
#  893: 'continental',
#  894: 'continually',
#  895: 'continue',
#  896: 'continued',
#  897: 'continues',
#  898: 'continuing',
#  899: 'continuous',
#  900: 'continuously',
#  901: 'contour',
#  902: 'contract',
#  903: 'contrary',
#  904: 'contrast',
#  905: 'control',
#  906: 'controlled',
#  907: 'controller',
#  908: 'controls',
#  909: 'convenience',
#  910: 'conveniences',
#  911: 'convenient',
#  912: 'conventional',
#  913: 'conversation',
#  914: 'convert',
#  915: 'convertable',
#  916: 'converter',
#  917: 'converters',
#  918: 'convertible',
#  919: 'convertibles',
#  920: 'convince',
#  921: 'convinced',
#  922: 'cool',
#  923: 'coolant',
#  924: 'cooled',
#  925: 'cooler',
#  926: 'coolest',
#  927: 'cooling',
#  928: 'cools',
#  929: 'cooper',
#  930: 'cord',
#  931: 'core',
#  932: 'corner',
#  933: 'cornering',
#  934: 'corners',
#  935: 'corolla',
#  936: 'corp',
#  937: 'corporate',
#  938: 'corporation',
#  939: 'correct',
#  940: 'corrected',
#  941: 'correctly',
#  942: 'corrosion',
#  943: 'corvette',
#  944: 'corvettes',
#  945: 'cosmetic',
#  946: 'cost',
#  947: 'costco',
#  948: 'costing',
#  949: 'costly',
#  950: 'costs',
#  951: 'couldn',
#  952: 'count',
#  953: 'counting',
#  954: 'countless',
#  955: 'country',
#  956: 'county',
#  957: 'coupe',
#  958: 'coupes',
#  959: 'couple',
#  960: 'coupled',
#  961: 'course',
#  962: 'courtesy',
#  963: 'cousin',
#  964: 'cover',
#  965: 'coverage',
#  966: 'covered',
#  967: 'covering',
#  968: 'covers',
#  969: 'cpo',
#  970: 'cr',
#  971: 'crack',
#  972: 'cracked',
#  973: 'cracking',
#  974: 'cracks',
#  975: 'craftsmanship',
#  976: 'cramped',
#  977: 'crank',
#  978: 'crap',
#  979: 'crappy',
#  980: 'crash',
#  981: 'crawl',
#  982: 'crazy',
#  983: 'creaking',
#  984: 'creaks',
#  985: 'create',
#  986: 'created',
#  987: 'creates',
#  988: 'creating',
#  989: 'creature',
#  990: 'credit',
#  991: 'crew',
#  992: 'crisis',
#  993: 'crisp',
#  994: 'criteria',
#  995: 'critical',
#  996: 'criticism',
#  997: 'critics',
#  998: 'cross',
#  999: 'crossed',
#  ...}

# %%
len(index_to_vocab)
# Out:
# 5000

# %%
def create_unique_cars_list(data):
    cars_list = []
    for car in data:
        cars_list.append(car['Year_Make_Model'])
    return cars_list

# %%
unique_cars = create_unique_cars_list(data)
cars_reverse_index = {car: i for i, car in enumerate(unique_cars)}

# %%
sizes = ['Compact', 'Midsize', 'Large']
size_reverse_index = {size: i for i, size in enumerate(sizes)}

# %%
def create_sizes_list(data, size_rev_idx):
    size_list = []
    for car in data:
        s = size_rev_idx[car['Vehicle Size']]
        size_list.append((car['Year_Make_Model'], s, car['MSRP']))
    
    return size_list

# %%
unfiltered_list = create_sizes_list(data,size_reverse_index)

# %%
def build_inverted_index(msgs):
    inverted_index = {}
    for index, msg in enumerate(msgs):
        tokens = msg['Tokenized Reviews']
        tokens_set = set(tokens)
        for token in tokens_set:
            if token not in inverted_index:
                inverted_index[token] = [(index, tokens.count(token))]
            else:
                inverted_index[token].append((index, tokens.count(token)))
    return inverted_index

# %%
def compute_idf(inv_idx, n_docs, min_df=10, max_df_ratio=0.95):
    idf_dict = {}
    for term, tf_list in inv_idx.items():
        df = len(tf_list)
        if (df >= min_df and df/n_docs <= max_df_ratio):
            frac = n_docs/(1+df)
            idf = math.log(frac, 2)
            idf_dict[term] = idf
            
    return idf_dict

# %%
inv_idx = build_inverted_index(data[0:5])

# %%
idf_dict = compute_idf(inv_idx, len(data[0:5]))

# %%
with open("data/unfiltered_list.json", "w+") as file:
    file.write(dumps(list(unfiltered_list)))

# %%
with open("data/keywords.json", "w+") as file:
    file.write(dumps(list(index_to_vocab.values())))

# %%
np.save("data/doc_by_vocab.json",doc_by_vocab)

# %%
with open("data/index_to_vocab.json", "w+") as file:
    file.write(dumps(index_to_vocab))

# %%
with open("data/idf_dict.json", "w+") as file:
    file.write(dumps(idf_dict))
